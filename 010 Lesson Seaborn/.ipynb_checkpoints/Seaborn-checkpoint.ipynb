# %% [markdown]
# We will import the Seaborn library with the following command

# %%
# Seaborn for plotting and styling
import seaborn as sns

# %% [markdown]
# # Importing Datasets -Import in-built datasets from seaborn

# %% [markdown]
# * Seaborn comes with a few important datasets in the library. When Seaborn is installed, the datasets download automatically.
# * You can use any of these datasets for your learning.

# %%
#  here is how we can get a list of all datasets that are in-built in Seaborn
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %% [markdown]
# * With the help of the following function you can load the required dataset
#
# load_dataset()

# %%
df = sns.load_dataset('car_crashes')
# print 5 rows
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# # Styling and Themes in Seaborn

# %% [markdown]
# * People are more likely to concentrate on beautiful and attractive visualizations rather than dull plots thus styling can be considered as a vital component of data visualization.
# * Seaborn comes packed with customized themes and a high-level interface for customizing and controlling the look of Matplotlib figures.

# %% [markdown]
# * Seaborn supports various themes that can make styling the plots really easy and save a lot of time.
# * Using the set_style() function of Seaborn we can set any of the themes available on Seaborn library.

# %% [markdown]
# Here are a few of the popular themes:
#
#     * darkgrid
#     * whitegrid
#     * dark
#     * white
#     * ticks

# %%
# Let us try applying these themes

#load dataset tips 
tips = sns.load_dataset('tips')

# preset themes
sns.set_style('darkgrid')

# plot 
sns.stripplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Seaborn’s plotting functions

# %% [markdown]
# # Relational plots¶

# %% [markdown]
# Understanding how the variables in the dataset relate each other and their relationships

# %% [markdown]
# * relplot  - Figure-level interface for drawing relational plots onto a FacetGrid.
# * scatterplot -Draw a scatter plot with possibility of several semantic groupings.
# * lineplot  -Draw a line plot with possibility of several semantic groupings.

# %% [markdown]
# ### Relplot  (figure level  function)

# %% [markdown]
# The kind parameter selects the underlying axes-level function to use:
#
# * scatterplot() ( kind=”scatter”)
# * lineplot() ( kind=”line”)

# %%
# The default plot kind is a scatterplot:
sns.relplot(x="total_bill", y="tip", hue="day", data=tips,col="time")

# %% [markdown]
# ### scatterplot (axes-level function)

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### lineplot (axes-level function)

# %%
sns.lineplot(data=tips, x="total_bill", y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Distribution plots

# %% [markdown]
# Suitable for comparing range and distribution for groups of numerical data

# %% [markdown]
# * displot -Figure-level interface for drawing distribution plots onto a FacetGrid.
# * histplot -Plot univariate or bivariate histograms to show distributions of datasets.
# * kdeplot -Plot univariate or bivariate distributions using kernel density estimation.
# * ecdfplot - Plot empirical cumulative distribution functions.ECDF represents the proportion or count of observations falling               below each unique value in a dataset.
# * rugplot -Plot marginal distributions by drawing ticks along the x and y axes.

# %% [markdown]
# ### Displot (figure level function)

# %%
# The default plot kind is a histogram:
penguins = sns.load_dataset("penguins")
sns.displot(data=penguins, x="flipper_length_mm")

# %% [markdown]
# ### ecdfplot (axes-level function)

# %%
sns.ecdfplot(data=penguins, x="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Proportion'>

# %% [markdown]
# ### kdeplot  (axes-level function)

# %%
sns.kdeplot(data=penguins, x="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %% [markdown]
# # Categorical plots

# %% [markdown]
# * catplot  Figure-level interface for drawing categorical plots onto a FacetGrid.
# * stripplot  Draw a scatterplot where one variable is categorical.
# * swarmploT -Draw a categorical scatterplot with non-overlapping points.
# * boxplot  -Draw a box plot to show distributions with respect to categories.
# * violinplot - Draw a combination of boxplot and kernel density estimate.
# * boxenplot  -Draw an enhanced box plot for larger datasets.
# * pointplot  -Show point estimates and confidence intervals using scatter plot glyphs.
# * barplot   -Show point estimates and confidence intervals as rectangular bars.
# * countplot  -Show the counts of observations in each categorical bin using bars.

# %% [markdown]
# ### Catplot    (figure level function)

# %% [markdown]
# Categorical scatterplots:
#
#   * stripplot() (with kind="strip"; the default)
#
#   * swarmplot() (with kind="swarm")
#
# Categorical distribution plots:
#
# We have three different kinds of categorical distribution plots, box plots and violin plots. These kinds of plots allow us to choose a numerical variable, like age, and plot the distribution of age for each category in a selected categorical variable.
#
#    * boxplot() (with kind="box")
#
#    * violinplot() (with kind="violin")
#
#    * boxenplot() (with kind="boxen")
#
# Categorical estimate plots:
#
#    * pointplot() (with kind="point")
#
#    * barplot() (with kind="bar")
#
#    * countplot() (with kind="count")

# %%
# catplot default 
exercise = sns.load_dataset("exercise")
g = sns.catplot(x="time", y="pulse", hue="kind", data=exercise)

# %% [markdown]
# ### Boxplot  (axes-level function)

# %%
sns.boxplot(x=tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# ### Barplot ((axes-level function)

# %%
sns.barplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Regression plots

# %% [markdown]
# Creates a regression line between 2 parameters and helps to visualize their linear relationships

# %% [markdown]
# * lmplot  -Plot data and regression model fits across a FacetGrid.
# * regplot -Plot data and a linear regression model fit.
# * residplot -Plot the residuals of a linear regression.

# %% [markdown]
# ### lmplot (figure level function)

# %%
# default 
sns.lmplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# ### Regplot(axes-level function)

# %%
sns.residplot (x="total_bill", y="tip", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Matrix plots

# %% [markdown]
# A matrix plot is an array of scatterplots.  effective when you are only interested in relationships among certain pairings                                       of variables.

# %% [markdown]
# * heatmap  -Plot rectangular data as a color-encoded matrix.
# * clustermap -Plot a matrix dataset as a hierarchically-clustered heatmap.

# %% [markdown]
# ### Heatmap

# %% [markdown]
# Better visualize the volume of locations/events within a dataset and assist in directing viewers towards areas on data visualizations that matter most.

# %%
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
flights.head(3)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419

# %%
sns.heatmap(flights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# ### Clustermap

# %% [markdown]
# Method uses a hierarchical clusters to order data by similarity. This reorganizes the data for the rows and columns and displays similar content next to one another for even more depth of understanding the data

# %%
iris = sns.load_dataset("iris")
species = iris.pop("species")
g = sns.clustermap(iris)

# %% [markdown]
# # Multi-plot grids

# %% [markdown]
# * Facet grids  -  Multi-plot grid for plotting conditional relationships.
# * Pair grids   -  	Plot pairwise relationships in a dataset.
# * Joint grids  - 	 Draw a plot of two variables with bivariate and univariate graphs.

# %% [markdown]
# ### Facet grid

# %%
# Calling the constructor requires a long-form data object. This initializes the grid, but doesn’t plot anything on it:
sns.FacetGrid(tips)

#Assign column and/or row variables to add more subplots to the figure:
face=sns.FacetGrid(tips, col="time", row="sex")

#To draw a plot on every facet, pass a function and the name of one or more columns in the dataframe to FacetGrid.map()
face.map(sns.scatterplot, "total_bill", "tip")

# %% [markdown]
# #### example 2

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map_dataframe(sns.histplot, x="total_bill")
g.set_axis_labels("Total bill", "Count")

# %% [markdown]
# ### Pair plot

# %%
penguins = sns.load_dataset("penguins")
sns.pairplot(penguins)

# %% [markdown]
#  Assigning a hue variable adds a semantic mapping and changes the default marginal plot to a layered kernel density estimate (KDE):

# %%
sns.pairplot(penguins, hue="species")

# %% [markdown]
# ### Joint grid

# %% [markdown]
# An object managing multiple subplots that correspond to joint and marginal axes for plotting a bivariate relationship or distribution.

# %%
penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

# %%
sns.jointplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species")
